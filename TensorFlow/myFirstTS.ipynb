# %% [markdown]
# # Meu primeiro programa no TS
#
# Um exemplo de aprendizado supervisionado com um problema de _________ (regressão?)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# Criando uma rede sequencial que possui apenas uma camada e um neurônio.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units = 1, input_shape = [1])])

# %% [markdown]
# # Definindo a funçnao de custo e de otimização.
#
# Aplicando 'mean squared error' e 'stochastic gradient descent'

# %%
model.compile(optimizer = 'sgd', loss = 'mean_squared_error')

# %% [markdown]
# # Provendo os dados.
# Uma feature apenas com seis target.

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype = float)

ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype = float)

# %% [markdown]
# # Treinando a rede
#
# Para a rede aprender usaremos 'model.fit'. A função receberá as features e o target como paramentros, assim como os número de interações (epochs).

# %%
model.fit(xs, ys, epochs = 500)
# Out:
# 21
# Epoch 270/500
# 6/6 [==============================] - 0s 732us/sample - loss: 0.0021
# Epoch 271/500
# 6/6 [==============================] - 0s 1ms/sample - loss: 0.0020
# Epoch 272/500
# 6/6 [==============================] - 0s 1ms/sample - loss: 0.0020
# Epoch 273/500
# 6/6 [==============================] - 0s 933us/sample - loss: 0.0020
# Epoch 274/500
# 6/6 [==============================] - 0s 732us/sample - loss: 0.0019
# Epoch 275/500
# 6/6 [==============================] - 0s 984us/sample - loss: 0.0019
# Epoch 276/500
# 6/6 [==============================] - 0s 857us/sample - loss: 0.0018
# Epoch 277/500
# 6/6 [==============================] - 0s 1ms/sample - loss: 0.0018
# Epoch 278/500
# 6/6 [==============================] - 0s 1ms/sample - loss: 0.0018
# Epoch 279/500
# 6/6 [==============================] - 0s 782us/sample - loss: 0.0017
# Epoch 280/500
# 6/6 [==============================] - 0s 1ms/sample - loss: 0.0017
# Epoch 281/500
# ...

# %% [markdown]
# Após o modelo ser treinado podemos usar a função 'model.predict' para prever 'Y' para um dado novo 'X'.

# %%
print(model.predict([10.0]))
# Out:
# [[18.987745]]
